# %% [markdown]
# <a href="https://colab.research.google.com/github/JadoHR/Personal_Projects_Jean_De_Dieu/blob/main/arrays_lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python program to check if the number is an Armstrong number or not

 # take input from the user
num = int(input("Enter a number: "))

 # initialize sum
sum = 0

 # find the sum of the cube of each digit
temp = num
while temp > 0:
    digit = temp % 10
    sum += digit ** 3
    temp //= 10

 # display the result
if num == sum:
    print(num,"is an Armstrong number")
else:
    print(num,"is not an Armstrong number")
# Out:
# Enter a number: 4
# 4 is not an Armstrong number

# %%
# Creating a list
fruits = ["apple", "banana", "cherry"]

# Accessing elements in a list by index
print(fruits[0])  # Output: "apple"
print(fruits[1])  # Output: "banana"
print(fruits[2])  # Output: "cherry"

# Modifying elements in a list
fruits[1] = "orange"
print(fruits)  # Output: ["apple", "orange", "cherry"]

# Adding elements to a list
fruits.append("grape")
print(fruits)  # Output: ["apple", "orange", "cherry", "grape"]

# Removing elements from a list
fruits.remove("apple")
print(fruits)  # Output: ["orange", "cherry", "grape"]

# Checking if an element exists in a list
if "banana" in fruits:
    print("Banana is in the list.")
else:
    print("Banana is not in the list.")

# Iterating through a list using a for loop
for fruit in fruits:
    print(fruit)

# Getting the length of a list
num_fruits = len(fruits)
print("Number of fruits:", num_fruits)

# Sorting a list
fruits.sort()
print(fruits)  # Output: ["cherry", "grape", "orange"]

# Reversing a list
fruits.reverse()
print(fruits)  # Output: ["orange", "grape", "cherry"]
# Out:
# apple
# banana
# cherry
# ['apple', 'orange', 'cherry']
# ['apple', 'orange', 'cherry', 'grape']
# ['orange', 'cherry', 'grape']
# Banana is not in the list.
# orange
# cherry
# grape
# Number of fruits: 3
# ['cherry', 'grape', 'orange']
# ['orange', 'grape', 'cherry']
